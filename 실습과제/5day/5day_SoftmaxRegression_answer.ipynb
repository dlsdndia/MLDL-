# %% [markdown]
# 문제) 제공 되는 'auto-mpg.csv' 파일에 대하여 EDA를 수행 후 소프트맥스 회귀 모델을 구현
#       - ‘horsepower’를 저출력, 보통출력, 고출력을 갖는 범주형을 추가한 후 소프트맥스 회귀 모델을 작성

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing

from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers

# %%
# IPython 디스플레이 설정 - 출력할 열의 개수 한도 늘리기
pd.set_option( 'display.max_columns', 10 )

# %% [markdown]
# # softmax 회귀 모델

# %% [markdown]
# ## 1. 데이터 준비

# %%
# csv파일 데이터프레임으로 변환
raw_df = pd.read_csv( 'auto-mpg.csv', header = None, encoding = 'utf-8' )

# %%
# 열이름 지정
raw_df.columns = [ 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
               'acceleration', 'model', 'origin', 'name' ]

# %%
raw_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8         307.0      130.0  3504.0          12.0     70
# 1  15.0          8         350.0      165.0  3693.0          11.5     70
# 2  18.0          8         318.0      150.0  3436.0          11.0     70
# 3  16.0          8         304.0      150.0  3433.0          12.0     70
# 4  17.0          8         302.0      140.0  3449.0          10.5     70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df = raw_df.copy()

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8         307.0      130.0  3504.0          12.0     70
# 1  15.0          8         350.0      165.0  3693.0          11.5     70
# 2  18.0          8         318.0      150.0  3436.0          11.0     70
# 3  16.0          8         304.0      150.0  3433.0          12.0     70
# 4  17.0          8         302.0      140.0  3449.0          10.5     70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### 'name'변수 제거

# %%
df.pop( 'name' )
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 398, dtype: object

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8         307.0      130.0  3504.0          12.0     70
# 1  15.0          8         350.0      165.0  3693.0          11.5     70
# 2  18.0          8         318.0      150.0  3436.0          11.0     70
# 3  16.0          8         304.0      150.0  3433.0          12.0     70
# 4  17.0          8         302.0      140.0  3449.0          10.5     70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## 2. 데이터 탐색

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model         398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#             model      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# #### 엔진 출력인 'horsepower' 변수가 포함되어 있지 않으므로 자료형 변경

# %%
df[ 'horsepower' ].unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '?', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
df[ 'horsepower' ].replace( '?', np.nan, inplace = True )
df.dropna( subset = [ 'horsepower' ], axis = 0, inplace = True )
df[ 'horsepower' ].unique()
# Out:
# array(['130.0', '165.0', '150.0', '140.0', '198.0', '220.0', '215.0',
#        '225.0', '190.0', '170.0', '160.0', '95.00', '97.00', '85.00',
#        '88.00', '46.00', '87.00', '90.00', '113.0', '200.0', '210.0',
#        '193.0', '100.0', '105.0', '175.0', '153.0', '180.0', '110.0',
#        '72.00', '86.00', '70.00', '76.00', '65.00', '69.00', '60.00',
#        '80.00', '54.00', '208.0', '155.0', '112.0', '92.00', '145.0',
#        '137.0', '158.0', '167.0', '94.00', '107.0', '230.0', '49.00',
#        '75.00', '91.00', '122.0', '67.00', '83.00', '78.00', '52.00',
#        '61.00', '93.00', '148.0', '129.0', '96.00', '71.00', '98.00',
#        '115.0', '53.00', '81.00', '79.00', '120.0', '152.0', '102.0',
#        '108.0', '68.00', '58.00', '149.0', '89.00', '63.00', '48.00',
#        '66.00', '139.0', '103.0', '125.0', '133.0', '138.0', '135.0',
#        '142.0', '77.00', '62.00', '132.0', '84.00', '64.00', '74.00',
#        '116.0', '82.00'], dtype=object)

# %%
df[ 'horsepower' ] = df[ 'horsepower' ].astype( 'float' )

# %%
origin = df.pop( 'origin' )

# %%
df['USA'] = ( origin == 1 ) * 1.0
df['Europe'] = ( origin == 2 ) * 1.0
df['Japan'] = ( origin == 3 ) * 1.0

# %%
# np.histogram 함수로 3개의 bin으로 나누는 경계값의 리스트 생성
count, bin_dividers = np.histogram( df[ 'horsepower' ], bins = 3 )

# %%
bin_names = [ '저출력', '보통출력', '고출력' ]

# %%
# pd.cut으로 각 데이터를 3개의 bin에 할당
df[ 'hp_bin' ] = pd.cut( x = df[ 'horsepower' ],
                         bins = bin_dividers,
                         labels = bin_names,
                         include_lowest = True )

# %%
df[ 'hp_bin' ] = df[ 'hp_bin' ].replace(['저출력','보통출력', '고출력'], [ 0, 1, 2 ] )
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  ...  model  USA  Europe  \
# 0  18.0          8         307.0       130.0  3504.0  ...     70  1.0     0.0
# 1  15.0          8         350.0       165.0  3693.0  ...     70  1.0     0.0
# 2  18.0          8         318.0       150.0  3436.0  ...     70  1.0     0.0
# 3  16.0          8         304.0       150.0  3433.0  ...     70  1.0     0.0
# 4  17.0          8         302.0       140.0  3449.0  ...     70  1.0     0.0
#
#    Japan  hp_bin
# 0    0.0       1
# 1    0.0       1
# 2    0.0       1
# 3    0.0       1
# 4    0.0       1
#
# [5 rows x 11 columns]

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  ...  model  USA  \
# 393  27.0          4         140.0        86.0  2790.0  ...     82  1.0
# 394  44.0          4          97.0        52.0  2130.0  ...     82  0.0
# 395  32.0          4         135.0        84.0  2295.0  ...     82  1.0
# 396  28.0          4         120.0        79.0  2625.0  ...     82  1.0
# 397  31.0          4         119.0        82.0  2720.0  ...     82  1.0
#
#      Europe  Japan  hp_bin
# 393     0.0    0.0       0
# 394     1.0    0.0       0
# 395     0.0    0.0       0
# 396     0.0    0.0       0
# 397     0.0    0.0       0
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    float64
#  5   acceleration  392 non-null    float64
#  6   model         392 non-null    int64
#  7   USA           392 non-null    float64
#  8   Europe        392 non-null    float64
#  9   Japan         392 non-null    float64
#  10  hp_bin        392 non-null    int64
# dtypes: float64(8), int64(3)
# memory usage: 36.8 KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  ...  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000  ...
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184  ...
# std      7.805007    1.705783    104.644004   38.491160   849.402560  ...
# min      9.000000    3.000000     68.000000   46.000000  1613.000000  ...
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000  ...
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000  ...
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000  ...
# max     46.600000    8.000000    455.000000  230.000000  5140.000000  ...
#
#             model         USA      Europe       Japan      hp_bin
# count  392.000000  392.000000  392.000000  392.000000  392.000000
# mean    75.979592    0.625000    0.173469    0.201531    0.426020
# std      3.683737    0.484742    0.379136    0.401656    0.639402
# min     70.000000    0.000000    0.000000    0.000000    0.000000
# 25%     73.000000    0.000000    0.000000    0.000000    0.000000
# 50%     76.000000    1.000000    0.000000    0.000000    0.000000
# 75%     79.000000    1.000000    0.000000    0.000000    1.000000
# max     82.000000    1.000000    1.000000    1.000000    2.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# ### 훈련용 데이터 셋과 테스트용 데이터 셋 분리

# %%
train_df = df.sample( frac = 0.8, random_state = 0 )
test_df = df.drop( train_df.index )

# %%
print( 'train data 개수 : {:5d}'.format( len( train_df ) ) )
print( 'test data 개수 : {:5d}'.format( len( test_df ) ) )
# Out:
# train data 개수 :   314
# test data 개수 :    78

# %%
# 학습용 데이터
train_df.head()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  ...  model  USA  \
# 146  28.0          4          90.0        75.0  2125.0  ...     74  1.0
# 282  22.3          4         140.0        88.0  2890.0  ...     79  1.0
# 69   12.0          8         350.0       160.0  4456.0  ...     72  1.0
# 378  38.0          4         105.0        63.0  2125.0  ...     82  1.0
# 331  33.8          4          97.0        67.0  2145.0  ...     80  0.0
#
#      Europe  Japan  hp_bin
# 146     0.0    0.0       0
# 282     0.0    0.0       0
# 69      0.0    0.0       1
# 378     0.0    0.0       0
# 331     0.0    1.0       0
#
# [5 rows x 11 columns]

# %%
# 테스트용 데이터
test_df.head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  ...  model  USA  \
# 9   15.0          8         390.0       190.0  3850.0  ...     70  1.0
# 25  10.0          8         360.0       215.0  4615.0  ...     70  1.0
# 28   9.0          8         304.0       193.0  4732.0  ...     70  1.0
# 31  25.0          4         113.0        95.0  2228.0  ...     71  0.0
# 33  19.0          6         232.0       100.0  2634.0  ...     71  1.0
#
#     Europe  Japan  hp_bin
# 9      0.0    0.0       2
# 25     0.0    0.0       2
# 28     0.0    0.0       2
# 31     0.0    1.0       0
# 33     0.0    0.0       0
#
# [5 rows x 11 columns]

# %% [markdown]
# ## 3. 속성 선택
#
# - softmax 회귀 모델 변수로 사용할 후보 변수를 선택한다.
# - 예측 목표 변수인 종속 변수( y )가 될 'hp_bin' 변수와 독립 변수( X )로 사용할 후보로 3개 변수(  'cylinders', 'displacement', 'horsepower', 'weight' )를 포함

# %%
df = train_df[ [ 'hp_bin', 'cylinders', 'displacement', 'horsepower', 'weight' ] ]
df.head()
# Out:
#      hp_bin  cylinders  displacement  horsepower  weight
# 146       0          4          90.0        75.0  2125.0
# 282       0          4         140.0        88.0  2890.0
# 69        1          8         350.0       160.0  4456.0
# 378       0          4         105.0        63.0  2125.0
# 331       0          4          97.0        67.0  2145.0

# %%
df.describe()
# Out:
#            hp_bin   cylinders  displacement  horsepower       weight
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean     0.426752    5.477707    195.318471  104.869427  2990.251592
# std      0.631483    1.699788    104.331589   38.096214   843.898596
# min      0.000000    3.000000     68.000000   46.000000  1649.000000
# 25%      0.000000    4.000000    105.500000   76.250000  2256.500000
# 50%      0.000000    4.000000    151.000000   94.500000  2822.500000
# 75%      1.000000    8.000000    265.750000  128.000000  3608.000000
# max      2.000000    8.000000    455.000000  225.000000  5140.000000

# %% [markdown]
# ### 정규화

# %%
df_stats = df.describe()
df_stats.pop( "hp_bin" )
df_stats = df_stats.transpose()
df_stats
# Out:
#               count         mean         std     min      25%     50%  \
# cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
#
#                   75%     max
# cylinders        8.00     8.0
# displacement   265.75   455.0
# horsepower     128.00   225.0
# weight        3608.00  5140.0

# %% [markdown]
# ### y( Label ) 분리

# %%
y_train = np.asarray( train_df.pop( 'hp_bin' ) )
y_test = np.asarray( test_df.pop( 'hp_bin' ) )

# %%
# y에 대한 One-Hot encoding
y_train = to_categorical( y_train )
y_test = to_categorical( y_test )

# %%
print( len( y_train ), len( y_test ) )
# Out:
# 314 78

# %%
def normalization( x ):
  return ( x - df_stats[ 'mean' ] ) / df_stats[ 'std' ]

normed_train_df = normalization( train_df )
normed_test_df = normalization( test_df )

# %% [markdown]
# ## 4. 모델 학습

# %% [markdown]
# ### 훈련 / 테스트 데이터 NumPy  배열로 변환

# %% [markdown]
# # softmax 회귀 모델

# %% [markdown]
# ### 훈련 / 테스트 데이터 NumPy  배열로 변환

# %%
X_train = np.asarray( normed_train_df[ [ 'cylinders', 'displacement', 'horsepower', 'weight' ] ] ) 
X_test = np.asarray( normed_test_df[ [  'cylinders', 'displacement', 'horsepower', 'weight'  ] ] )

# %%
print( len( X_train ), len( X_test ) )
# Out:
# 314 78

# %%
print( len( y_train ), len( y_test ) )
# Out:
# 314 78

# %% [markdown]
# ### Keras 모델구성

# %%
X_train = np.array( X_train )
X_test = np.array( X_test )

# %%
model = Sequential()
model.add( Dense( 3, input_dim = 4, activation = 'softmax' ) )
sgd = optimizers.SGD( lr = 0.0001 )
model.compile( optimizer = 'adam' ,loss = 'categorical_crossentropy', metrics = [ 'accuracy' ] )
history = model.fit( X_train, y_train, batch_size = 1, epochs = 200, validation_split = 0.2 )
# Out:
# Train on 251 samples, validate on 63 samples
# Epoch 1/200
# 251/251 [==============================] - 1s 3ms/sample - loss: 0.6904 - accuracy: 0.7610 - val_loss: 0.6719 - val_accuracy: 0.6825
# Epoch 2/200
# 251/251 [==============================] - 0s 2ms/sample - loss: 0.5667 - accuracy: 0.7809 - val_loss: 0.5799 - val_accuracy: 0.6984
# Epoch 3/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.5037 - accuracy: 0.7809 - val_loss: 0.5292 - val_accuracy: 0.7460
# Epoch 4/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.4628 - accuracy: 0.8008 - val_loss: 0.4978 - val_accuracy: 0.7619
# Epoch 5/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.4336 - accuracy: 0.8048 - val_loss: 0.4664 - val_accuracy: 0.7619
# Epoch 6/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.4106 - accuracy: 0.8167 - val_loss: 0.4547 - val_accuracy: 0.7619
# Epoch 7/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3912 - accuracy: 0.8406 - val_loss: 0.4316 - val_accuracy: 0.7937
# Epoch 8/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3748 - accuracy: 0.8606 - val_loss: 0.4234 - val_accuracy: 0.7937
# Epoch 9/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3607 - accuracy: 0.8645 - val_loss: 0.4092 - val_accuracy: 0.7937
# Epoch 10/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3476 - accuracy: 0.8725 - val_loss: 0.3952 - val_accuracy: 0.8254
# Epoch 11/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3366 - accuracy: 0.8845 - val_loss: 0.3859 - val_accuracy: 0.8254
# Epoch 12/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3258 - accuracy: 0.8964 - val_loss: 0.3828 - val_accuracy: 0.8254
# Epoch 13/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3165 - accuracy: 0.9044 - val_loss: 0.3774 - val_accuracy: 0.8254
# Epoch 14/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.3080 - accuracy: 0.9004 - val_loss: 0.3662 - val_accuracy: 0.8254
# Epoch 15/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2998 - accuracy: 0.9124 - val_loss: 0.3497 - val_accuracy: 0.8254
# Epoch 16/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2925 - accuracy: 0.9124 - val_loss: 0.3430 - val_accuracy: 0.8254
# Epoch 17/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2853 - accuracy: 0.9163 - val_loss: 0.3334 - val_accuracy: 0.8254
# Epoch 18/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2787 - accuracy: 0.9163 - val_loss: 0.3266 - val_accuracy: 0.8254
# Epoch 19/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2720 - accuracy: 0.9163 - val_loss: 0.3198 - val_accuracy: 0.8254
# Epoch 20/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2666 - accuracy: 0.9163 - val_loss: 0.3149 - val_accuracy: 0.8254
# Epoch 21/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2607 - accuracy: 0.9203 - val_loss: 0.3140 - val_accuracy: 0.8254
# Epoch 22/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2551 - accuracy: 0.9203 - val_loss: 0.3033 - val_accuracy: 0.8254
# Epoch 23/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2498 - accuracy: 0.9203 - val_loss: 0.2970 - val_accuracy: 0.8254
# Epoch 24/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2451 - accuracy: 0.9203 - val_loss: 0.2931 - val_accuracy: 0.8254
# Epoch 25/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2399 - accuracy: 0.9203 - val_loss: 0.2855 - val_accuracy: 0.8254
# Epoch 26/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2352 - accuracy: 0.9283 - val_loss: 0.2852 - val_accuracy: 0.8413
# Epoch 27/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2309 - accuracy: 0.9243 - val_loss: 0.2779 - val_accuracy: 0.8413
# Epoch 28/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2266 - accuracy: 0.9283 - val_loss: 0.2707 - val_accuracy: 0.8571
# Epoch 29/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2222 - accuracy: 0.9402 - val_loss: 0.2681 - val_accuracy: 0.8571
# Epoch 30/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2184 - accuracy: 0.9402 - val_loss: 0.2658 - val_accuracy: 0.8571
# Epoch 31/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2145 - accuracy: 0.9402 - val_loss: 0.2605 - val_accuracy: 0.8571
# Epoch 32/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2108 - accuracy: 0.9402 - val_loss: 0.2575 - val_accuracy: 0.8571
# Epoch 33/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2071 - accuracy: 0.9402 - val_loss: 0.2527 - val_accuracy: 0.8571
# Epoch 34/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2036 - accuracy: 0.9402 - val_loss: 0.2496 - val_accuracy: 0.8571
# Epoch 35/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.2006 - accuracy: 0.9402 - val_loss: 0.2412 - val_accuracy: 0.8571
# Epoch 36/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1972 - accuracy: 0.9442 - val_loss: 0.2383 - val_accuracy: 0.8571
# Epoch 37/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1942 - accuracy: 0.9442 - val_loss: 0.2350 - val_accuracy: 0.8571
# Epoch 38/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1912 - accuracy: 0.9482 - val_loss: 0.2299 - val_accuracy: 0.8571
# Epoch 39/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1882 - accuracy: 0.9482 - val_loss: 0.2247 - val_accuracy: 0.8571
# Epoch 40/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1854 - accuracy: 0.9482 - val_loss: 0.2258 - val_accuracy: 0.8571
# Epoch 41/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1828 - accuracy: 0.9482 - val_loss: 0.2235 - val_accuracy: 0.8571
# Epoch 42/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1802 - accuracy: 0.9482 - val_loss: 0.2177 - val_accuracy: 0.8571
# Epoch 43/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1776 - accuracy: 0.9482 - val_loss: 0.2162 - val_accuracy: 0.8571
# Epoch 44/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1750 - accuracy: 0.9522 - val_loss: 0.2151 - val_accuracy: 0.8571
# Epoch 45/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1729 - accuracy: 0.9522 - val_loss: 0.2107 - val_accuracy: 0.8571
# Epoch 46/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1701 - accuracy: 0.9562 - val_loss: 0.2148 - val_accuracy: 0.8571
# Epoch 47/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1683 - accuracy: 0.9522 - val_loss: 0.2087 - val_accuracy: 0.8571
# Epoch 48/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1659 - accuracy: 0.9522 - val_loss: 0.2033 - val_accuracy: 0.8571
# Epoch 49/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1636 - accuracy: 0.9522 - val_loss: 0.2033 - val_accuracy: 0.8571
# Epoch 50/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1617 - accuracy: 0.9562 - val_loss: 0.1992 - val_accuracy: 0.8571
# Epoch 51/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1597 - accuracy: 0.9641 - val_loss: 0.1958 - val_accuracy: 0.8730
# Epoch 52/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1580 - accuracy: 0.9602 - val_loss: 0.1946 - val_accuracy: 0.8889
# Epoch 53/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1560 - accuracy: 0.9641 - val_loss: 0.1903 - val_accuracy: 0.8889
# Epoch 54/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1541 - accuracy: 0.9602 - val_loss: 0.1901 - val_accuracy: 0.8889
# Epoch 55/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1522 - accuracy: 0.9641 - val_loss: 0.1904 - val_accuracy: 0.8730
# Epoch 56/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1505 - accuracy: 0.9641 - val_loss: 0.1840 - val_accuracy: 0.8889
# Epoch 57/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1488 - accuracy: 0.9641 - val_loss: 0.1818 - val_accuracy: 0.8889
# Epoch 58/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1471 - accuracy: 0.9641 - val_loss: 0.1802 - val_accuracy: 0.8889
# Epoch 59/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1458 - accuracy: 0.9641 - val_loss: 0.1810 - val_accuracy: 0.8889
# Epoch 60/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1443 - accuracy: 0.9681 - val_loss: 0.1770 - val_accuracy: 0.8889
# Epoch 61/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1425 - accuracy: 0.9681 - val_loss: 0.1735 - val_accuracy: 0.8889
# Epoch 62/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1408 - accuracy: 0.9681 - val_loss: 0.1755 - val_accuracy: 0.8889
# Epoch 63/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1397 - accuracy: 0.9681 - val_loss: 0.1718 - val_accuracy: 0.8889
# Epoch 64/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1381 - accuracy: 0.9681 - val_loss: 0.1718 - val_accuracy: 0.8889
# Epoch 65/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1367 - accuracy: 0.9681 - val_loss: 0.1706 - val_accuracy: 0.8889
# Epoch 66/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1353 - accuracy: 0.9641 - val_loss: 0.1681 - val_accuracy: 0.8889
# Epoch 67/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1341 - accuracy: 0.9641 - val_loss: 0.1675 - val_accuracy: 0.8889
# Epoch 68/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1329 - accuracy: 0.9641 - val_loss: 0.1598 - val_accuracy: 0.9048
# Epoch 69/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1316 - accuracy: 0.9641 - val_loss: 0.1650 - val_accuracy: 0.9048
# Epoch 70/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1303 - accuracy: 0.9641 - val_loss: 0.1605 - val_accuracy: 0.9048
# Epoch 71/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1292 - accuracy: 0.9641 - val_loss: 0.1551 - val_accuracy: 0.9206
# Epoch 72/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1281 - accuracy: 0.9641 - val_loss: 0.1534 - val_accuracy: 0.9206
# Epoch 73/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1268 - accuracy: 0.9641 - val_loss: 0.1589 - val_accuracy: 0.9048
# Epoch 74/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1255 - accuracy: 0.9641 - val_loss: 0.1581 - val_accuracy: 0.9048
# Epoch 75/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1246 - accuracy: 0.9641 - val_loss: 0.1536 - val_accuracy: 0.9048
# Epoch 76/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1235 - accuracy: 0.9641 - val_loss: 0.1538 - val_accuracy: 0.9048
# Epoch 77/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1226 - accuracy: 0.9681 - val_loss: 0.1501 - val_accuracy: 0.9206
# Epoch 78/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1212 - accuracy: 0.9641 - val_loss: 0.1497 - val_accuracy: 0.9048
# Epoch 79/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1204 - accuracy: 0.9681 - val_loss: 0.1460 - val_accuracy: 0.9206
# Epoch 80/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1194 - accuracy: 0.9681 - val_loss: 0.1470 - val_accuracy: 0.9206
# Epoch 81/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1185 - accuracy: 0.9681 - val_loss: 0.1474 - val_accuracy: 0.9048
# Epoch 82/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1177 - accuracy: 0.9681 - val_loss: 0.1426 - val_accuracy: 0.9206
# Epoch 83/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1165 - accuracy: 0.9681 - val_loss: 0.1451 - val_accuracy: 0.9206
# Epoch 84/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1159 - accuracy: 0.9721 - val_loss: 0.1444 - val_accuracy: 0.9206
# Epoch 85/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1149 - accuracy: 0.9721 - val_loss: 0.1470 - val_accuracy: 0.9048
# Epoch 86/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1141 - accuracy: 0.9721 - val_loss: 0.1433 - val_accuracy: 0.9048
# Epoch 87/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1129 - accuracy: 0.9761 - val_loss: 0.1383 - val_accuracy: 0.9206
# Epoch 88/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1121 - accuracy: 0.9721 - val_loss: 0.1406 - val_accuracy: 0.9206
# Epoch 89/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1115 - accuracy: 0.9721 - val_loss: 0.1401 - val_accuracy: 0.9206
# Epoch 90/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1106 - accuracy: 0.9761 - val_loss: 0.1412 - val_accuracy: 0.9048
# Epoch 91/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1098 - accuracy: 0.9761 - val_loss: 0.1377 - val_accuracy: 0.9206
# Epoch 92/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1088 - accuracy: 0.9761 - val_loss: 0.1363 - val_accuracy: 0.9206
# Epoch 93/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1083 - accuracy: 0.9761 - val_loss: 0.1382 - val_accuracy: 0.9048
# Epoch 94/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1075 - accuracy: 0.9801 - val_loss: 0.1304 - val_accuracy: 0.9365
# Epoch 95/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1067 - accuracy: 0.9801 - val_loss: 0.1326 - val_accuracy: 0.9206
# Epoch 96/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1059 - accuracy: 0.9801 - val_loss: 0.1319 - val_accuracy: 0.9206
# Epoch 97/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1054 - accuracy: 0.9801 - val_loss: 0.1306 - val_accuracy: 0.9365
# Epoch 98/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1046 - accuracy: 0.9801 - val_loss: 0.1330 - val_accuracy: 0.9206
# Epoch 99/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1040 - accuracy: 0.9801 - val_loss: 0.1319 - val_accuracy: 0.9206
# Epoch 100/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1031 - accuracy: 0.9801 - val_loss: 0.1292 - val_accuracy: 0.9206
# Epoch 101/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1028 - accuracy: 0.9801 - val_loss: 0.1270 - val_accuracy: 0.9365
# Epoch 102/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1018 - accuracy: 0.9801 - val_loss: 0.1276 - val_accuracy: 0.9365
# Epoch 103/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1012 - accuracy: 0.9801 - val_loss: 0.1251 - val_accuracy: 0.9365
# Epoch 104/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1008 - accuracy: 0.9801 - val_loss: 0.1275 - val_accuracy: 0.9206
# Epoch 105/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.1000 - accuracy: 0.9801 - val_loss: 0.1287 - val_accuracy: 0.9206
# Epoch 106/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0996 - accuracy: 0.9801 - val_loss: 0.1271 - val_accuracy: 0.9206
# Epoch 107/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0988 - accuracy: 0.9801 - val_loss: 0.1234 - val_accuracy: 0.9365
# Epoch 108/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0983 - accuracy: 0.9801 - val_loss: 0.1246 - val_accuracy: 0.9365
# Epoch 109/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0977 - accuracy: 0.9801 - val_loss: 0.1214 - val_accuracy: 0.9365
# Epoch 110/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0969 - accuracy: 0.9801 - val_loss: 0.1189 - val_accuracy: 0.9365
# Epoch 111/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0965 - accuracy: 0.9801 - val_loss: 0.1179 - val_accuracy: 0.9524
# Epoch 112/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0961 - accuracy: 0.9801 - val_loss: 0.1186 - val_accuracy: 0.9365
# Epoch 113/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0951 - accuracy: 0.9801 - val_loss: 0.1198 - val_accuracy: 0.9365
# Epoch 114/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0950 - accuracy: 0.9801 - val_loss: 0.1148 - val_accuracy: 0.9524
# Epoch 115/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0942 - accuracy: 0.9801 - val_loss: 0.1180 - val_accuracy: 0.9365
# Epoch 116/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0937 - accuracy: 0.9801 - val_loss: 0.1165 - val_accuracy: 0.9365
# Epoch 117/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0930 - accuracy: 0.9801 - val_loss: 0.1212 - val_accuracy: 0.9206
# Epoch 118/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0927 - accuracy: 0.9801 - val_loss: 0.1198 - val_accuracy: 0.9365
# Epoch 119/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0922 - accuracy: 0.9801 - val_loss: 0.1182 - val_accuracy: 0.9365
# Epoch 120/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0916 - accuracy: 0.9801 - val_loss: 0.1158 - val_accuracy: 0.9365
# Epoch 121/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0912 - accuracy: 0.9801 - val_loss: 0.1192 - val_accuracy: 0.9206
# Epoch 122/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0908 - accuracy: 0.9801 - val_loss: 0.1150 - val_accuracy: 0.9365
# Epoch 123/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0904 - accuracy: 0.9801 - val_loss: 0.1159 - val_accuracy: 0.9365
# Epoch 124/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0900 - accuracy: 0.9801 - val_loss: 0.1147 - val_accuracy: 0.9365
# Epoch 125/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0895 - accuracy: 0.9801 - val_loss: 0.1121 - val_accuracy: 0.9365
# Epoch 126/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0890 - accuracy: 0.9801 - val_loss: 0.1097 - val_accuracy: 0.9683
# Epoch 127/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0883 - accuracy: 0.9801 - val_loss: 0.1114 - val_accuracy: 0.9365
# Epoch 128/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0882 - accuracy: 0.9801 - val_loss: 0.1137 - val_accuracy: 0.9365
# Epoch 129/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0875 - accuracy: 0.9801 - val_loss: 0.1113 - val_accuracy: 0.9365
# Epoch 130/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0873 - accuracy: 0.9801 - val_loss: 0.1120 - val_accuracy: 0.9365
# Epoch 131/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0867 - accuracy: 0.9801 - val_loss: 0.1102 - val_accuracy: 0.9524
# Epoch 132/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0865 - accuracy: 0.9801 - val_loss: 0.1090 - val_accuracy: 0.9524
# Epoch 133/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0859 - accuracy: 0.9801 - val_loss: 0.1086 - val_accuracy: 0.9524
# Epoch 134/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0854 - accuracy: 0.9801 - val_loss: 0.1070 - val_accuracy: 0.9683
# Epoch 135/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0852 - accuracy: 0.9801 - val_loss: 0.1100 - val_accuracy: 0.9524
# Epoch 136/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0846 - accuracy: 0.9801 - val_loss: 0.1086 - val_accuracy: 0.9524
# Epoch 137/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0842 - accuracy: 0.9801 - val_loss: 0.1085 - val_accuracy: 0.9524
# Epoch 138/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0839 - accuracy: 0.9801 - val_loss: 0.1094 - val_accuracy: 0.9524
# Epoch 139/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0837 - accuracy: 0.9801 - val_loss: 0.1097 - val_accuracy: 0.9365
# Epoch 140/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0836 - accuracy: 0.9801 - val_loss: 0.1058 - val_accuracy: 0.9524
# Epoch 141/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0826 - accuracy: 0.9801 - val_loss: 0.1034 - val_accuracy: 0.9683
# Epoch 142/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0829 - accuracy: 0.9801 - val_loss: 0.1034 - val_accuracy: 0.9683
# Epoch 143/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0823 - accuracy: 0.9801 - val_loss: 0.1025 - val_accuracy: 0.9683
# Epoch 144/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0817 - accuracy: 0.9801 - val_loss: 0.1009 - val_accuracy: 0.9683
# Epoch 145/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0818 - accuracy: 0.9801 - val_loss: 0.0988 - val_accuracy: 0.9683
# Epoch 146/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0810 - accuracy: 0.9801 - val_loss: 0.1046 - val_accuracy: 0.9524
# Epoch 147/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0806 - accuracy: 0.9801 - val_loss: 0.1031 - val_accuracy: 0.9524
# Epoch 148/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0803 - accuracy: 0.9801 - val_loss: 0.1037 - val_accuracy: 0.9524
# Epoch 149/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0799 - accuracy: 0.9801 - val_loss: 0.1027 - val_accuracy: 0.9524
# Epoch 150/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0798 - accuracy: 0.9801 - val_loss: 0.1009 - val_accuracy: 0.9683
# Epoch 151/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0792 - accuracy: 0.9801 - val_loss: 0.1001 - val_accuracy: 0.9683
# Epoch 152/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0790 - accuracy: 0.9801 - val_loss: 0.0985 - val_accuracy: 0.9683
# Epoch 153/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0786 - accuracy: 0.9801 - val_loss: 0.1004 - val_accuracy: 0.9524
# Epoch 154/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0785 - accuracy: 0.9801 - val_loss: 0.1018 - val_accuracy: 0.9524
# Epoch 155/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0782 - accuracy: 0.9801 - val_loss: 0.1028 - val_accuracy: 0.9524
# Epoch 156/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0779 - accuracy: 0.9841 - val_loss: 0.1040 - val_accuracy: 0.9524
# Epoch 157/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0773 - accuracy: 0.9801 - val_loss: 0.1011 - val_accuracy: 0.9524
# Epoch 158/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0770 - accuracy: 0.9801 - val_loss: 0.0989 - val_accuracy: 0.9524
# Epoch 159/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0772 - accuracy: 0.9801 - val_loss: 0.0974 - val_accuracy: 0.9683
# Epoch 160/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0765 - accuracy: 0.9801 - val_loss: 0.1032 - val_accuracy: 0.9524
# Epoch 161/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0760 - accuracy: 0.9801 - val_loss: 0.0962 - val_accuracy: 0.9683
# Epoch 162/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0758 - accuracy: 0.9801 - val_loss: 0.0983 - val_accuracy: 0.9524
# Epoch 163/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0756 - accuracy: 0.9801 - val_loss: 0.0986 - val_accuracy: 0.9524
# Epoch 164/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0752 - accuracy: 0.9841 - val_loss: 0.1013 - val_accuracy: 0.9524
# Epoch 165/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0749 - accuracy: 0.9801 - val_loss: 0.1021 - val_accuracy: 0.9524
# Epoch 166/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0751 - accuracy: 0.9801 - val_loss: 0.1009 - val_accuracy: 0.9524
# Epoch 167/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0745 - accuracy: 0.9801 - val_loss: 0.0990 - val_accuracy: 0.9524
# Epoch 168/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0744 - accuracy: 0.9801 - val_loss: 0.0979 - val_accuracy: 0.9524
# Epoch 169/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0740 - accuracy: 0.9801 - val_loss: 0.0971 - val_accuracy: 0.9524
# Epoch 170/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0738 - accuracy: 0.9801 - val_loss: 0.1017 - val_accuracy: 0.9524
# Epoch 171/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0734 - accuracy: 0.9801 - val_loss: 0.0966 - val_accuracy: 0.9524
# Epoch 172/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0732 - accuracy: 0.9801 - val_loss: 0.0948 - val_accuracy: 0.9683
# Epoch 173/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0730 - accuracy: 0.9801 - val_loss: 0.0950 - val_accuracy: 0.9524
# Epoch 174/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0725 - accuracy: 0.9801 - val_loss: 0.0956 - val_accuracy: 0.9524
# Epoch 175/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0725 - accuracy: 0.9801 - val_loss: 0.0959 - val_accuracy: 0.9524
# Epoch 176/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0723 - accuracy: 0.9801 - val_loss: 0.0938 - val_accuracy: 0.9683
# Epoch 177/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0720 - accuracy: 0.9801 - val_loss: 0.0969 - val_accuracy: 0.9524
# Epoch 178/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0716 - accuracy: 0.9801 - val_loss: 0.0959 - val_accuracy: 0.9524
# Epoch 179/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0714 - accuracy: 0.9801 - val_loss: 0.0951 - val_accuracy: 0.9524
# Epoch 180/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0713 - accuracy: 0.9801 - val_loss: 0.0943 - val_accuracy: 0.9524
# Epoch 181/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0709 - accuracy: 0.9801 - val_loss: 0.0934 - val_accuracy: 0.9524
# Epoch 182/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0706 - accuracy: 0.9801 - val_loss: 0.0949 - val_accuracy: 0.9524
# Epoch 183/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0705 - accuracy: 0.9801 - val_loss: 0.0925 - val_accuracy: 0.9524
# Epoch 184/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0703 - accuracy: 0.9841 - val_loss: 0.0941 - val_accuracy: 0.9524
# Epoch 185/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0699 - accuracy: 0.9801 - val_loss: 0.0953 - val_accuracy: 0.9524
# Epoch 186/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0697 - accuracy: 0.9801 - val_loss: 0.0931 - val_accuracy: 0.9524
# Epoch 187/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0694 - accuracy: 0.9801 - val_loss: 0.0926 - val_accuracy: 0.9524
# Epoch 188/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0693 - accuracy: 0.9841 - val_loss: 0.0920 - val_accuracy: 0.9524
# Epoch 189/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0692 - accuracy: 0.9801 - val_loss: 0.0922 - val_accuracy: 0.9524
# Epoch 190/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0689 - accuracy: 0.9841 - val_loss: 0.0952 - val_accuracy: 0.9524
# Epoch 191/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0686 - accuracy: 0.9801 - val_loss: 0.0936 - val_accuracy: 0.9524
# Epoch 192/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0682 - accuracy: 0.9880 - val_loss: 0.0955 - val_accuracy: 0.9524
# Epoch 193/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0681 - accuracy: 0.9801 - val_loss: 0.0946 - val_accuracy: 0.9524
# Epoch 194/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0679 - accuracy: 0.9801 - val_loss: 0.0921 - val_accuracy: 0.9524
# Epoch 195/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0677 - accuracy: 0.9801 - val_loss: 0.0899 - val_accuracy: 0.9524
# Epoch 196/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0676 - accuracy: 0.9801 - val_loss: 0.0899 - val_accuracy: 0.9524
# Epoch 197/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0675 - accuracy: 0.9880 - val_loss: 0.0912 - val_accuracy: 0.9524
# Epoch 198/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0670 - accuracy: 0.9841 - val_loss: 0.0927 - val_accuracy: 0.9524
# Epoch 199/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0669 - accuracy: 0.9801 - val_loss: 0.0920 - val_accuracy: 0.9524
# Epoch 200/200
# 251/251 [==============================] - 0s 1ms/sample - loss: 0.0667 - accuracy: 0.9801 - val_loss: 0.0902 - val_accuracy: 0.9524

# %%
loss = history.history[ 'loss' ]
val_loss = history.history[ 'val_loss' ]

epochs = range( 1, len( history.history[ 'accuracy' ] ) + 1 )

# %%
plt.plot( epochs, loss, 'b', label = 'Training loss' )
plt.plot( epochs, val_loss, 'r', label = 'Training loss' )
plt.title( 'Training and validation loss' )
plt.xlabel( 'Epochs' )
plt.ylabel( 'Loss' )
plt.legend()

plt.show()

# %%
hist = pd.DataFrame(history.history)
hist[ 'epoch' ] = history.epoch
hist.tail()
# Out:
#          loss  accuracy  val_loss  val_accuracy  epoch
# 195  0.067613  0.980080  0.089920      0.952381    195
# 196  0.067535  0.988048  0.091232      0.952381    196
# 197  0.067041  0.984064  0.092662      0.952381    197
# 198  0.066921  0.980080  0.091988      0.952381    198
# 199  0.066675  0.980080  0.090216      0.952381    199

# %% [markdown]
# # 5. 평가

# %%
print( '테스트 정확도 : {:.4f}'.format( model.evaluate( X_test, y_test )[ 1 ] ) )
# Out:
# 78/1 [====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 2ms/sample - loss: 0.0590 - accuracy: 0.9615
# 테스트 정확도 : 0.9615
